# %% [markdown]
# <a href="https://colab.research.google.com/github/uvaissha/Data-science/blob/main/iplauctionanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipl=pd.read_csv("iplauction2023.csv")

# %%
ipl.shape
# Out:
# (309, 7)

# %%
ipl.columns
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
ipl.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count            151.000000             238.000000
# mean              59.205298             368.067227
# std               59.688337             449.070117
# min               20.000000              20.000000
# 25%               20.000000              21.250000
# 50%               20.000000             150.000000
# 75%               75.000000             625.000000
# max              200.000000            1850.000000

# %%
ipl.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
ipl.dtypes
# Out:
# name                      object
# player style              object
# nationality               object
# base price (in lacs)     float64
# final price (in lacs)    float64
# franchise                 object
# status                    object
# dtype: object

# %%
ipl.isnull().sum()
# Out:
# name                       0
# player style               0
# nationality                0
# base price (in lacs)     158
# final price (in lacs)     71
# franchise                 71
# status                     0
# dtype: int64

# %%
ipl['base price (in lacs)'].fillna(ipl['base price (in lacs)'].median(),inplace=True)
ipl['final price (in lacs)'].fillna(0,inplace=True)
ipl['franchise'].fillna("unknown",inplace=True)
# Out:
# <ipython-input-11-edb34d1e955d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['base price (in lacs)'].fillna(ipl['base price (in lacs)'].median(),inplace=True)
# <ipython-input-11-edb34d1e955d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
ipl.isnull().sum()
# Out:
# name                     0
# player style             0
# nationality              0
# base price (in lacs)     0
# final price (in lacs)    0
# franchise                0
# status                   0
# dtype: int64

# %%
ipl
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                  20.0
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                  20.0
# 305        Moeen Ali   Allrounder       England                  20.0
# 306  Ruturaj Gaikwad       Batter         India                  20.0
# 307     Rishabh Pant    WK-Batter         India                  20.0
# 308       Axar Patel   Allrounder         India                  20.0
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
ipl.columns
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
ipl['player style'].value_counts()
# Out:
# player style
# Bowler        111
# Allrounder    103
# Batter         55
# WK-Batter      40
# Name: count, dtype: int64

# %%
ipl['nationality'].value_counts()
# Out:
# nationality
# India           201
# England          24
# South Africa     19
# West Indies      14
# Australia        14
# New Zealand      11
# Sri Lanka         8
# Afghanistan       7
# Bangladesh        4
# Ireland           2
# Zimbabwe          2
# Namibia           1
# Netherlands       1
# Singapore         1
# Name: count, dtype: int64

# %%
ipl['franchise'].value_counts()
# Out:
# franchise
# unknown    71
# RR         25
# SRH        25
# LSG        25
# CSK        25
# RCB        25
# GT         25
# DC         24
# MI         23
# PBKS       22
# KKR        19
# Name: count, dtype: int64

# %%
ipl['status'].value_counts()
# Out:
# status
# RETAINED    158
# SOLD         80
# UNSOLD       71
# Name: count, dtype: int64

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(12,6))
sns.histplot(ipl['base price (in lacs)'],bins=30,color='blue',label='base price')

plt.title('Distribution of Base Price ')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(ipl['final price (in lacs)'],bins=30,color='green',label='final price')

plt.title('Distribution of final  Price ')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="player style",data=ipl,palette="Set2")
plt.title("Player Style Distribution")
plt.xlabel("Player Style")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-28-3ea2a7ae0fbb>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="player style",data=ipl,palette="Set2")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="franchise",data=ipl,palette="viridis")
plt.title("franchise Distribution")
plt.xlabel("franchise")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-29-1dbf25018503>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="franchise",data=ipl,palette="viridis")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="nationality",data=ipl,palette="coolwarm")
plt.xticks(rotation=45)
plt.title("nationality Distribution")
plt.xlabel("nationality")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-32-2e4ca49d1d2b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="nationality",data=ipl,palette="coolwarm")

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="base price (in lacs)",y="final price (in lacs)",data=ipl,hue="status",color="red")
plt.title("Base Price vs Final Price")
plt.xlabel("Base Price")
plt.ylabel("Final Price")
# Out:
# Text(0, 0.5, 'Final Price')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=ipl[['base price (in lacs)', 'final price (in lacs)']])
plt.title("Base Price vs Final Price")
plt.xlabel("Base Price")
plt.ylabel("Final Price")
plt.show()

# %%
# Calculate the IQR for each column
Q1_base = ipl['base price (in lacs)'].quantile(0.25)
Q3_base = ipl['base price (in lacs)'].quantile(0.75)
IQR_base = Q3_base - Q1_base

# Calculate lower and upper bounds for 'base price (in lacs)'
lower_bound_base = Q1_base - 1.5 * IQR_base
upper_bound_base = Q3_base + 1.5 * IQR_base

# Find outliers for 'base price (in lacs)'
outliers_base = ipl[(ipl['base price (in lacs)'] < lower_bound_base) | (ipl['base price (in lacs)'] > upper_bound_base)]

print("Outliers in 'base price (in lacs)':")
print(outliers_base)

# Repeat for 'final price (in lacs)'
Q1_final = ipl['final price (in lacs)'].quantile(0.25)
Q3_final = ipl['final price (in lacs)'].quantile(0.75)
IQR_final = Q3_final - Q1_final

# Calculate lower and upper bounds for 'final price (in lacs)'
lower_bound_final = Q1_final - 1.5 * IQR_final
upper_bound_final = Q3_final + 1.5 * IQR_final

# Find outliers for 'final price (in lacs)'
outliers_final = ipl[(ipl['final price (in lacs)'] < lower_bound_final) | (ipl['final price (in lacs)'] > upper_bound_final)]

print("Outliers in 'final price (in lacs)':")
print(outliers_final)
# Out:
# Outliers in 'base price (in lacs)':
#                 name player style   nationality  base price (in lacs)  \
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# 7       Akeal Hosein       Bowler   West Indies                 100.0
# 10         Luke Wood       Bowler       England                 100.0
# ..               ...          ...           ...                   ...
# 147       Ben Stokes   Allrounder       England                 200.0
# 148    Cameron Green   Allrounder     Australia                 200.0
# 149    Sikandar Raza   Allrounder      Zimbabwe                  50.0
# 150       Sam Curran   Allrounder       England                 200.0
# 151      Harry Brook       Batter       England                 150.0
#
#      final price (in lacs) franchise  status
# ...

# %%
ipl[['name','final price (in lacs)']].sort_values(by='final price (in lacs)',ascending=False).head(10)
# Out:
#                 name  final price (in lacs)
# 150       Sam Curran                 1850.0
# 148    Cameron Green                 1750.0
# 292         KL Rahul                 1700.0
# 147       Ben Stokes                 1625.0
# 307     Rishabh Pant                 1600.0
# 290     Rohit Sharma                 1600.0
# 136  Nicholas Pooran                 1600.0
# 296  Ravindra Jadeja                 1600.0
# 230     Ishan Kishan                 1525.0
# 282      Virat Kohli                 1500.0

# %%
bowlers=ipl[ipl['player style']=='Bowler']

# %%
bowlers[['name','final price (in lacs)']].sort_values(by='final price (in lacs)',ascending=False).head(10)
# Out:
#                     name  final price (in lacs)
# 300          Rashid Khan                 1500.0
# 223        Deepak Chahar                 1400.0
# 288       Jasprit Bumrah                 1200.0
# 240        Harshal Patel                 1075.0
# 216      Prasidh Krishna                 1000.0
# 194           Avesh Khan                 1000.0
# 271        Kagiso Rabada                  925.0
# 297  Varun Chakaravarthy                  800.0
# 276          Trent Boult                  800.0
# 201         Jofra Archer                  800.0

# %%
batters=ipl[ipl['player style']=='Batter']
batters=batters.sort_values(by='final price (in lacs)',ascending=False)
batters.head(10)
# Out:
#                  name player style  nationality  base price (in lacs)  \
# 290      Rohit Sharma       Batter        India                  20.0
# 282       Virat Kohli       Batter        India                  20.0
# 151       Harry Brook       Batter      England                 150.0
# 272      Shreyas Iyer       Batter        India                  20.0
# 177     Shahrukh Khan       Batter        India                  20.0
# 160    Rahul Tripathi       Batter        India                  20.0
# 268   Shimron Hetmyer       Batter  West Indies                  20.0
# 131    Mayank Agarwal       Batter        India                 100.0
# 274    Shikhar Dhawan       Batter        India                  20.0
# 287  Suryakumar Yadav       Batter        India                  20.0
#
#      final price (in lacs) franchise    status
# 290                 1600.0        MI  RETAINED
# 282                 1500.0       RCB  RETAINED
# 151                 1325.0       SRH      SOLD
# ...
